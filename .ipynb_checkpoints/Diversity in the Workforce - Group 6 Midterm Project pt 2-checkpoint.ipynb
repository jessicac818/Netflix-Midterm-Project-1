# %%
#Importing all libraries needed
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Read HR file into DataFrame
file = os.path.join('Resources', 'HRDataset_v14.csv')
file

#This is our main file with HR Data
HR_data = pd.read_csv(file)
HR_data.head()
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0      Patronick, Lucas  10005          0                0         1
# 1      Bunbury, Jessica  10188          1                1         0
# 2  Baczenski, Rachael    10252          1                1         0
# 3         Barton, Nader  10066          0                2         1
# 4          Brill, Donna  10177          1                1         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            5       4            4                       1  108987  ...
# 1            5       6            3                       0   74326  ...
# 2            5       5            3                       1   54670  ...
# 3            5       5            3                       0   52505  ...
# 4            5       5            3                       0   53492  ...
#
#        ManagerName  ManagerID        RecruitmentSource PerformanceScore  \
# 0  Alex Sweetwater       10.0       Diversity Job Fair          Exceeds
# 1       John Smith       17.0            Google Search      Fully Meets
# 2    David Stanley       14.0       Diversity Job Fair      Fully Meets
# 3   Michael Albert       22.0  On-line Web application      Fully Meets
# 4    David Stanley       14.0            Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              5.00               5                    3
# 1              3.14               5                    0
# 2              4.20               4                    0
# 3              5.00               5                    0
# 4              3.35               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                    8/16/15              0       13
# 1                    2/10/13              1       19
# 2                    1/30/16              0       12
# 3                     3/2/17              0        1
# 4                     3/4/13              0        6
#
# [5 rows x 36 columns]

# %%
#Question 2: What is the overall diversity profile of the organization?

# %%
#Overall Diversity base on Ethnicity or Race. 
Race_Desc = HR_data.groupby(['RaceDesc']).count()
Race_Desc.reset_index(inplace = True)

# %%
Race_Desc
# Out:
#                            RaceDesc  Employee_Name  EmpID  MarriedID  \
# 0  American Indian or Alaska Native              3      3          3
# 1                             Asian             29     29         29
# 2         Black or African American             80     80         80
# 3                          Hispanic              1      1          1
# 4                 Two or more races             11     11         11
# 5                             White            187    187        187
#
#    MaritalStatusID  GenderID  EmpStatusID  DeptID  PerfScoreID  \
# 0                3         3            3       3            3
# 1               29        29           29      29           29
# 2               80        80           80      80           80
# 3                1         1            1       1            1
# 4               11        11           11      11           11
# 5              187       187          187     187          187
#
#    FromDiversityJobFairID  ...  ManagerName  ManagerID  RecruitmentSource  \
# 0                       3  ...            3          3                  3
# 1                      29  ...           29         26                 29
# 2                      80  ...           80         79                 80
# 3                       1  ...            1          1                  1
# 4                      11  ...           11         11                 11
# 5                     187  ...          187        183                187
#
#    PerformanceScore  EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 0                 3                 3                3                     3
# 1                29                29               29                    29
# 2                80                80               80                    80
# 3                 1                 1                1                     1
# 4                11                11               11                    11
# 5               187               187              187                   187
#
#    LastPerformanceReview_Date  DaysLateLast30  Absences
# 0                           3               3         3
# 1                          29              29        29
# 2                          80              80        80
# 3                           1               1         1
# 4                          11              11        11
# 5                         187             187       187
#
# [6 rows x 36 columns]

# %%
Race_Desc = Race_Desc.sort_values(by=['Employee_Name'],ascending=False)

# %%
fig = plt.figure(figsize = (16,8))
plt.bar(Race_Desc['RaceDesc'],Race_Desc['Employee_Name'])
# Out:
# <BarContainer object of 6 artists>

# %%
#Overall Diversity base on Gender and Department.
#Overall Diversity base on Gender and Recruitment Source.
#Overall Performance base on Recruitment Source.

# %%
Gender = HR_data.groupby(['GenderID']).count()
Gender.reset_index(inplace = True)
Gender
# Out:
#    GenderID  Employee_Name  EmpID  MarriedID  MaritalStatusID  EmpStatusID  \
# 0         0            176    176        176              176          176
# 1         1            135    135        135              135          135
#
#    DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  ManagerName  \
# 0     176          176                     176     176  ...          176
# 1     135          135                     135     135  ...          135
#
#    ManagerID  RecruitmentSource  PerformanceScore  EngagementSurvey  \
# 0        171                176               176               176
# 1        132                135               135               135
#
#    EmpSatisfaction  SpecialProjectsCount  LastPerformanceReview_Date  \
# 0              176                   176                         176
# 1              135                   135                         135
#
#    DaysLateLast30  Absences
# 0             176       176
# 1             135       135
#
# [2 rows x 36 columns]

# %%
#Overall Diversity base on Gender.
fig = plt.figure(figsize = (16,8))
plt.bar(Gender['GenderID'],Gender['RaceDesc'])
# Out:
# <BarContainer object of 2 artists>
